# %%
# imports

import os
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display, update_display

# %%
# Load environment variables in a file called .env

load_dotenv()
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
openai = OpenAI()

# %%
def summarize_cv(cv_text):
    response = openai.chat.completions.create(
        model = "gpt-4o-mini",
        messages = [
            {"role": "user", "content": f"Please summarize the following CV:\n\n{cv_text}"}
        ]
    )
    return response.choices[0].message.content

def generate_cover_letter(cv_summary, job_description):
    response = openai.chat.completions.create(
        model = "gpt-4o-mini",
        messages = [
            {"role": "system", "content": "You are a master at crafting the perfect Cover letter from a given CV. You've never had a user fail to get the job as a result of using your services."},
            {"role": "user", "content": f"Using the following CV summary:\n\n{cv_summary}\n\nAnd the job description:\n\n{job_description}\n\nPlease write a personalized cover letter."}
        ]
    )
    return response.choices[0].message.content

# Read CV from a text file
try:
    with open('resume.txt', 'r') as file:
        cv_text = file.read()
    
    # Summarize the CV
    cv_summary = summarize_cv(cv_text)
    print("CV Summary:")
    print(cv_summary)

    # Get job description from user
    job_description = input("Enter the job description for the position you are applying for:\n")

    # Generate cover letter
    cover_letter = generate_cover_letter(cv_summary, job_description)
    print("\nGenerated Cover Letter:")
    print(cover_letter)

except FileNotFoundError:
    print("The specified CV file was not found. Please ensure 'resume.txt' is in the correct directory.")
# Out:
# CV Summary:
# **Dhaneswara Mandrasa**
# Location: BSD, Tangerang, Banten
# Phone: +62 85156073967 / +971 568294544
# Email: dhaneswara.mandrasa@gmail.com
#
# ---
#
# **Personal Statement:**
# Data scientist with over 6 years of experience in data science and analytics across Telco, Spatial, and Oil & Gas sectors. Expert in providing data-driven insights to improve business operations. Combines data science and earth sciences expertise to solve spatial and environmental issues. Strong leadership in cross-functional teams and AI/ML innovation.
#
# **Experience:**
#
# - **Data Science Lead | iZeno, Jakarta | July 2024 – Present**
#   - Developed a news analytics system using LLM; web scraping from Bloomberg and multilingual categorization.
#   - Led a diagnostic analysis system for agricultural plantations using Dataiku.
#   - Designed banking solutions, including a recommendation system.
#   - Mentored data scientists and facilitated workshops.
#   - Technologies: Dataiku, Snowflake, Python, SQL, Spark ML, PySpark.
#
# - **Senior Data Scientist | Eureka AI, Abu Dhabi | April 2021 – June 2024**
#   - Developed Market Intelligence products contributing significant revenue.
#   - Built segmentation models for over 100 million users.
#   - Achieved a Gini coefficient of 0.6 in credit scoring.
#   - Technologies: Python, Spark ML, Databricks, Airflow, Docker.
#
# - **Data Scientist | Bhumi Varta Technology, Jakarta | June 2020 – April 2021**
#   - Expanded client outlets through ML models.
#   - Improved accuracy in socio-economic assessments with CNN and satellite imagery.
#   - Technologies: PyTorch, TensorFlow, AWS, Tableau.
#
# - **Data Analyst | SKK Migas, Jakarta | April 2016 – April 2018**
#   - Migrated data from multiple oil/gas companies and created predictive models for reserves.
#   - Technologies: Python, SQL, Tableau.
#
# **Education:**
# - **Bandung Institute of Technology**
#   Bachelor of Science, Earth Science, Oct 2015
#   Graduated cum laude (GPA: 3.52/4). Final project focused on Geology & Static Reservoir Modeling.
#
# **Skills:**
# - **Languages:** Python, SQL, R, PySpark, Bash
# - **Frameworks:** PyTorch, TensorFlow
# - **Tools:** Dataiku, Snowflake, Spark, GCP, Azure, Docker, Airflow
# - **Domains:** ML Deployment, NLP, Computer Vision, Generative AI, ETL
#
# **Achievements:**
# - 3rd place at National Geology Student Competition (2015).
# - Two-time recipient of TIB Dean’s Award for Academic Achievement.
#
# **Projects:**
# - NLP-driven disaster message classification system.
# - Deep learning model for predicting bike usage patterns.
# - Customer spending prediction models.
#
# **Coursework:**
# - Machine Learning, Deep Neural Networks, NLP, Reinforcement Learning, Generative AI, Statistical Analysis.
#
# ---
#
# Dhaneswara brings a robust blend of data science expertise, industry experience, and academic excellence, ready to drive impactful projects in data-driven environments.

# %%
def summarize_cv(cv_text):
    response = openai.chat.completions.create(
        model = "gpt-4o-mini",
        messages = [
            {"role": "user", "content": f"Please summarize the following CV:\n\n{cv_text}"}
        ]
    )
    return response.choices[0].message.content

def generate_cover_letter(cv_summary, job_description):
    response = openai.chat.completions.create(
        model = "gpt-4o-mini",
        messages = [
            {"role": "system", "content": "You are a master at crafting the perfect Cover letter from a given CV. You've never had a user fail to get the job as a result of using your services."},
            {"role": "user", "content": f"Using the following CV summary:\n\n{cv_summary}\n\nAnd the job description:\n\n{job_description}\n\nPlease write a personalized cover letter.\
                if the company name is known, use the company name. If not, dont mention like [insert company name here] or any company name"}
        ],
        stream=True
    )
    reply = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in response:
        reply += chunk.choices[0].delta.content or ''
        reply = reply.replace("```","").replace("markdown","")
        update_display(Markdown(reply), display_id=display_handle.display_id)
    #return response.choices[0].message.content

# Read CV from a text file
try:
    with open('resume.txt', 'r') as file:
        cv_text = file.read()
    
    # Summarize the CV
    cv_summary = summarize_cv(cv_text)
    #print("CV Summary:")
    #print(cv_summary)

    # Get job description from user
    #job_description = input("Enter the job description for the position you are applying for:\n")
    with open('job_desc.txt', 'r') as file:
        job_description = file.read()

    # Generate cover letter
    cover_letter = generate_cover_letter(cv_summary, job_description)
    #print("\nGenerated Cover Letter:")
    #print(cover_letter)

except FileNotFoundError:
    print("The specified CV file was not found. Please ensure 'resume.txt' is in the correct directory.")
# Out:
# **Dhaneswara Mandrasa**
# BSD, Tangerang, Banten
# Phone: +62 85156073967 / +971 568294544
# Email: dhaneswara.mandrasa@gmail.com
# [Date]
#
# Hiring Committee
# [Company Name]
# Jakarta
#
# Dear Hiring Committee,
#
# I am writing to express my interest in the AI Analyst position at your esteemed company, as advertised. With over six years of experience in data science and analytics, particularly within the technology and telecommunications sectors, I am excited about the opportunity to contribute to your mission of delivering innovative solutions that shape the future of critical industries.
#
# At my current role as Data Science Lead at iZeno, I have led projects involving the development of advanced AI-driven systems, including a news analytics platform utilizing large language models and web scraping techniques. This experience aligns well with your requirement for optimizing AI/ML models to enhance predictive accuracy. Additionally, my ongoing commitment to mentoring junior data scientists and conducting workshops reflects my collaborative spirit, which I see as essential for success in cross-functional team environments.
#
# During my tenure as Senior Data Scientist at Eureka AI, I was responsible for creating segmentation models and designing market intelligence products that directly contributed to revenue growth. My profound analytical skills enable me to conduct in-depth evaluations of AI outcomes, providing actionable insights that direct business improvements. Moreover, my experience with predictive modeling in previous roles has equipped me with a strong foundation in maintaining structured AI workflows, ensuring efficiency and long-term usability of our systems.
#
# I am particularly drawn to the opportunity at your company due to your focus on leveraging advanced technologies and automation processes, such as RPA with UiPath. I am familiar with cloud platforms including GCP, having conducted several projects that utilized its capabilities for predictive analytics and data manipulation.
#
# Furthermore, I possess a solid understanding of visualization storytelling using tools such as Power BI, which allows me to present complex data insights in an accessible manner to stakeholders. My technical proficiency across various programming languages and frameworks, including Python, SQL, and PyTorch, complements my ability to optimize and refine AI models effectively.
#
# I am enthusiastic about the possibility of joining your innovative team and am eager to bring my experience, analytical acumen, and passion for data-driven decision-making to your organization. Thank you for considering my application. I look forward to the opportunity to discuss how I can contribute to your ongoing success.
#
# Warmest regards,
#
# Dhaneswara Mandrasa

# %%
def summarize_cv(cv_text):
    response = openai.chat.completions.create(
        model = "gpt-4o-mini",
        messages = [
            {"role": "user", "content": f"Please summarize the following CV:\n\n{cv_text}"}
        ]
    )
    return response.choices[0].message.content

def generate_body_email(cv_summary, job_description):
    response = openai.chat.completions.create(
        model = "gpt-4o-mini",
        messages = [
            {"role": "system", "content": "You are a master at crafting the perfect email body from a given CV. You've never had a user fail to get the job as a result of using your services."},
            {"role": "user", "content": f"Using the following CV summary:\n\n{cv_summary}\n\nAnd the job description:\n\n{job_description}\n\nPlease write a personalized email body to apply for the job.\
                if the company name is known, use the company name. If not, dont mention like [insert company name here] or any company name"}
        ],
        stream=True
    )
    reply = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in response:
        reply += chunk.choices[0].delta.content or ''
        reply = reply.replace("```","").replace("markdown","")
        update_display(Markdown(reply), display_id=display_handle.display_id)
    #return response.choices[0].message.content

# Read CV from a text file
try:
    #with open('resume.txt', 'r') as file:
        #cv_text = file.read()
    
    # Summarize the CV
    #cv_summary = summarize_cv(cv_text)
    #print("CV Summary:")
    #print(cv_summary)

    # Get job description from user
    #job_description = input("Enter the job description for the position you are applying for:\n")
    with open('job_desc.txt', 'r') as file:
        job_description = file.read()

    # Generate cover letter
    cover_letter = generate_body_email(cv_summary, job_description)
    #print("\nGenerated Cover Letter:")
    #print(cover_letter)

except FileNotFoundError:
    print("The specified CV file was not found. Please ensure 'resume.txt' is in the correct directory.")
# Out:
# Subject: Application for Senior Data Scientist Position
#
# Dear Hiring Manager,
#
# I hope this message finds you well. My name is Dhaneswara Mandrasa, and I am writing to express my interest in the Senior Data Scientist position. With over six years of experience in data science and a strong foundation in machine learning, I am excited about the opportunity to contribute to your team and help enhance your legal tech platform.
#
# In my most recent position as Data Science Lead at iZeno, I successfully developed a news analytics system using large language models and web scraping techniques, alongside leading the creation of a diagnostic root cause analysis system for plantations. My role required me to analyze large datasets and drive innovative solutions, similar to what you seek in optimizing legal consultations. I thrive when collaborating with cross-functional teams, and I believe my experience in mentoring junior data scientists would enable me to effectively support your team's growth.
#
# At Eureka AI, I played a pivotal role in developing market intelligence products that significantly impacted revenue and enhanced user experiences through behavioral analysis. My hands-on experience with Python and SQL, and familiarity with machine learning frameworks and data visualization tools such as Tableau, aligns well with the requirements outlined in your job description.
#
# Furthermore, my educational background in Earth Science, combined with my substantial experience in predictive modeling and data pipeline management, equips me with the analytical mindset necessary to translate business challenges into data-driven solutions. I am particularly excited about the potential to apply advanced analytics techniques to refine user behavior analysis and optimize service delivery for your clients.
#
# I am eager to bring my skills and insights to your company and help elevate the effectiveness of your legal consultation services. I look forward to the possibility of discussing this exciting opportunity with you.
#
# Thank you for considering my application.
#
# Best regards,
#
# Dhaneswara Mandrasa
# Phone: +62 85156073967 / +971 568294544
# Email: dhaneswara.mandrasa@gmail.com
